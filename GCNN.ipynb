# %% [markdown]
# <a href="https://colab.research.google.com/github/PetchMa/deeplearning_fundamentals/blob/main/GCNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Graph Neural Network
# In this notebook we will try and rebuild a multilayered graph neural network from scratch using JAX once again. We begin by importing a few packages

# %%
import math
import jax
import jax.numpy as jnp
from jax import lax, random
from jax.experimental import stax
from jax.experimental.stax import Relu, LogSoftmax
from jax.nn.initializers import glorot_normal, glorot_uniform, normal, uniform, zeros
import jax.nn as nn
# Out:
# /usr/local/lib/python3.7/dist-packages/jax/experimental/stax.py:30: FutureWarning: jax.experimental.stax is deprecated, import jax.example_libraries.stax instead
#   FutureWarning)

# %% [markdown]
# # Layers
# We are going to start of constructing the graph neural network. We see that all a graph neural net is, is that it takes some given adjaceny matrix and multiplies it with the feature vectors which passes and aggregates data from adjacent nodes and then feeds this into a neural network.
#
# We first defined a dropout function. This randomly selects weights to drop and is meant to prevent over fitting the data. See that we randomly select from a distribution and then return the parameters that aren't zeroed out.
#
#
# Then we define the graph convolutional layer. In this layer we

# %%
def Dropout(rate):
    def init_fun(rng, input_shape):
        return input_shape, ()
    def apply_fun(params, inputs, is_training, **kwargs):
        rng = kwargs.get('rng', None)
        if rng is None:
            msg = ("Dropout layer requires apply_fun to be called with a PRNG key "
                   "argument. That is, instead of `apply_fun(params, inputs)`, call "
                   "it like `apply_fun(params, inputs, rng)` where `rng` is a "
                   "jax.random.PRNGKey value.")
            raise ValueError(msg)
        keep = random.bernoulli(rng, rate, inputs.shape)
        outs = jnp.where(keep, inputs / rate, 0)
        # if not training, just return inputs and discard any computation done
        out = lax.cond(is_training, outs, lambda x: x, inputs, lambda x: x)
        return out
    return init_fun, apply_fun

# %% [markdown]
# # Graph Layer
# Notice that the graph layer follows the simple step of 1) message passing 2) aggregation and 3) applying it to a feed forward neural network. We see that this can be easily done by writing the graph as an adjacency matrix ```adj``` and then matrix multiplying it with the feature vectors. Thus that is all we are doing! We linearly weight the input then apply the aggregation of near by adjacent nodes which is then passed on. This is in the apply function.
#
# We then see the initalize function which basically just creates a list of weights for the parameters.
#
# Layer constructor function for a Graph Convolution layer similar to https://arxiv.org/abs/1609.02907

# %%
def GraphConvolution(out_dim, bias=False):
    def matmul(A, B, shape):
      return jnp.matmul(A, B)

    def init_fun(rng, input_shape):
        output_shape = input_shape[:-1] + (out_dim,)
        k1, k2 = random.split(rng)
        W_init, b_init = glorot_uniform(), zeros
        W = W_init(k1, (input_shape[-1], out_dim))
        if bias:
            b = b_init(k2, (out_dim,))
        else:
            b = None
        return output_shape, (W, b)

    def apply_fun(params, x, adj, **kwargs):
        W, b = params
        support = jnp.dot(x, W)
        out = matmul(adj, support, support.shape[0])
        if bias:
            out += b
        return out

    return init_fun, apply_fun

# %% [markdown]
# # Building Feedforward
# Now we actually build and string together multiple layers of the neural networks. We see that in the initalize function we grab the initalized layers of graph neural nets. We loop through them and come out with the actual parameters
#
# We then look at the feed forward neaurl network. We take the apply function which is the ```gc_fun``` and we continue push the values and we stuff the parameters into the gc_fun function. We apply

# %%
def GCN(nhid, dropout):
    """
    This function implements the GCN model that uses 2 Graph Convolutional layers.
    The code is adapted from jax.experimental.stax.serial to be able to use
    the adjacency matrix as an argument to the GC layers but not the others.
    """
    gc_init = []
    gc_fun = []
    for i in range(len(nhid)):
      gc1_init, gc1_fun = GraphConvolution(nhid[i])
      gc_init.append(gc1_init)
      gc_fun.append(gc1_fun)
    
    _, drop_fun = Dropout(dropout)

    def init_fun(rng, input_shape):
        params = []
        for init_fun in gc_init:
            rng, layer_rng = random.split(rng)
            input_shape, param = init_fun(layer_rng, input_shape)
            params.append(param)
        return input_shape, params

    def apply_fun(params, x, adj, is_training=False, **kwargs):
        rng = kwargs.pop('rng', None)
        num_layers = len(gc_fun)-1
        k= random.split(rng, len(gc_fun)*2)
        
        for i in range(len(gc_fun)-1):
          x = gc_fun[i](params[i], x, adj, rng=k[(i+1)*2])
          x = nn.relu(x)
          x = drop_fun(None, x, is_training=is_training, rng=k[i*2])
          
        # x = drop_fun(None, x, is_training=is_training, rng=k[num_layers*2])
        x = gc_fun[num_layers](params[num_layers], x, adj, rng=k[(num_layers+1)*2])
        x = nn.log_softmax(x)
        return x
    
    return init_fun, apply_fun

# %% [markdown]
# # Loss Functions and Training

# %%
import argparse
import time
import numpy
import jax
import jax.numpy as jnp
from jax import jit, grad, random
from jax.experimental import optimizers
# Out:
# /usr/local/lib/python3.7/dist-packages/jax/experimental/optimizers.py:30: FutureWarning: jax.experimental.optimizers is deprecated, import jax.example_libraries.optimizers instead
#   FutureWarning)

# %% [markdown]
# # Loss Function
# We define two losses. One loss looks at the log probability likelyhood and thus preforms categorical cross entropy loss. We also have a L_2 normalization loss to regularize the models weights to prevent over fitting the model

# %%
@jit
def loss(params, batch):
    """
    The idxes of the batch indicate which nodes are used to compute the loss.
    """
    inputs, targets, adj, is_training, rng = batch
    preds = predict_fun(params, inputs, adj, is_training=is_training, rng=rng)
    ce_loss = -jnp.mean(jnp.sum(preds * targets, axis=1))
    l2_loss = 5e-4 * optimizers.l2_norm(params)**2 # tf doesn't use sqrt
    return ce_loss + l2_loss

@jit
def accuracy(params, batch):
    inputs, targets, adj, is_training, rng = batch
    target_class = jnp.argmax(targets, axis=1)
    predicted_class = jnp.argmax(predict_fun(params, inputs, adj, is_training=is_training, rng=rng), axis=1)
    return jnp.mean(predicted_class == target_class)

@jit
def loss_accuracy(params, batch):
    inputs, targets, adj, is_training, rng = batch
    preds = predict_fun(params, inputs, adj, is_training=is_training, rng=rng)
    target_class = jnp.argmax(targets, axis=1)
    predicted_class = jnp.argmax(preds, axis=1)
    ce_loss = -jnp.mean(jnp.sum(preds * targets, axis=1))
    acc = jnp.mean(predicted_class == target_class)
    return ce_loss, acc

# %% [markdown]
# # Load Data
# This part is all boilerplate code. This has nothing really to do with the algorithm but is just messaging the data and manipulating the data to actually run the model trained on it.
#
# The dataset is the research paper citation dataset.
#
# THIS IS NOT MY CODE THIS CODE IS MEANT TO LOAD THE DATA AND INTERFACE WITH THE DATA

# %%
# !git clone https://github.com/gcucurull/jax-gcn.git
import sys
import pickle as pkl
from pathlib import Path

import numpy as np
import scipy.sparse as sp
import networkx as nx


def encode_onehot(labels):
    classes = set(labels)
    classes_dict = {c: np.identity(len(classes))[i, :] for i, c in
                    enumerate(classes)}
    labels_onehot = np.array(list(map(classes_dict.get, labels)),
                             dtype=np.int32)
    return labels_onehot


def parse_index_file(filename):
    """Parse index file."""
    index = []
    for line in open(filename):
        index.append(int(line.strip()))
    return index


def normalize(mx):
    """Row-normalize sparse matrix"""
    rowsum = np.array(mx.sum(1))
    r_inv = np.power(rowsum, -1).flatten()
    r_inv[np.isinf(r_inv)] = 0.
    r_mat_inv = sp.diags(r_inv)
    mx = r_mat_inv.dot(mx)
    return mx


def preprocess_features(features):
    """Row-normalize feature matrix."""
    rowsum = np.array(features.sum(1))
    r_inv = np.power(rowsum, -1).flatten()
    r_inv[np.isinf(r_inv)] = 0.
    r_mat_inv = sp.diags(r_inv)
    features = r_mat_inv.dot(features)
    return features


def normalize_adj(adj):
    """Symmetrically normalize adjacency matrix."""
    adj = sp.coo_matrix(adj)
    rowsum = np.array(adj.sum(1))
    d_inv_sqrt = np.power(rowsum, -0.5).flatten()
    d_inv_sqrt[np.isinf(d_inv_sqrt)] = 0.
    d_mat_inv_sqrt = sp.diags(d_inv_sqrt)
    return adj.dot(d_mat_inv_sqrt).transpose().dot(d_mat_inv_sqrt).tocoo()


def preprocess_adj(adj):
    """Preprocessing of adjacency matrix for simple GCN model."""
    adj_normalized = normalize_adj(adj + sp.eye(adj.shape[0]))
    return adj_normalized


def to_sparse(adj):
    return (adj.nonzero(), adj.data)


def load_data(dataset_str: str = 'cora', sparse: bool = False):
    """
    Loads input data from gcn/data directory
    ind.dataset_str.x => the feature vectors of the training instances as scipy.sparse.csr.csr_matrix object;
    ind.dataset_str.tx => the feature vectors of the test instances as scipy.sparse.csr.csr_matrix object;
    ind.dataset_str.allx => the feature vectors of both labeled and unlabeled training instances
        (a superset of ind.dataset_str.x) as scipy.sparse.csr.csr_matrix object;
    ind.dataset_str.y => the one-hot labels of the labeled training instances as numpy.ndarray object;
    ind.dataset_str.ty => the one-hot labels of the test instances as numpy.ndarray object;
    ind.dataset_str.ally => the labels for instances in ind.dataset_str.allx as numpy.ndarray object;
    ind.dataset_str.graph => a dict in the format {index: [index_of_neighbor_nodes]} as collections.defaultdict
        object;
    ind.dataset_str.test.index => the indices of test instances in graph, for the inductive setting as list object.
    All objects above must be saved using python pickle module.
    :param dataset_str: Dataset name
    :return: All data input files loaded (as well the training/test data).
    """
    names = ['x', 'y', 'tx', 'ty', 'allx', 'ally', 'graph']
    objects = []
    for i in range(len(names)):
        with open("jax-gcn/data/ind.{}.{}".format(dataset_str, names[i]), 'rb') as f:
            if sys.version_info > (3, 0):
                objects.append(pkl.load(f, encoding='latin1'))
            else:
                objects.append(pkl.load(f))

    x, y, tx, ty, allx, ally, graph = tuple(objects)
    test_idx_reorder = parse_index_file("jax-gcn/data/ind.{}.test.index".format(dataset_str))
    test_idx_range = np.sort(test_idx_reorder)

    if dataset_str == 'citeseer':
        # Fix citeseer dataset (there are some isolated nodes in the graph)
        # Find isolated nodes, add them as zero-vecs into the right position
        test_idx_range_full = range(min(test_idx_reorder), max(test_idx_reorder)+1)
        tx_extended = sp.lil_matrix((len(test_idx_range_full), x.shape[1]))
        tx_extended[test_idx_range-min(test_idx_range), :] = tx
        tx = tx_extended
        ty_extended = np.zeros((len(test_idx_range_full), y.shape[1]))
        ty_extended[test_idx_range-min(test_idx_range), :] = ty
        ty = ty_extended

    features = sp.vstack((allx, tx)).tolil()
    features[test_idx_reorder, :] = features[test_idx_range, :]
    adj = nx.adjacency_matrix(nx.from_dict_of_lists(graph))

    labels = np.vstack((ally, ty))
    labels[test_idx_reorder, :] = labels[test_idx_range, :]

    idx_test = test_idx_range.tolist()
    idx_train = range(len(y))
    idx_val = range(len(y), len(y)+500)

    # features = normalize(features)
    # adj = normalize(adj.astype(np.float32) + sp.eye(adj.shape[0]))
    features = preprocess_features(features)
    adj = preprocess_adj(adj)

    if sparse:
        adj = to_sparse(adj) # custom format
    else:
        adj = np.asarray(adj.todense())

    features = np.asarray(features.todense())

    return adj, features, labels, list(idx_train), list(idx_val), idx_test

adj, features, labels,idx_train, idx_val, idx_test = load_data()
print(features.shape)
print(adj.shape)
print(labels.shape)
# Out:
# Cloning into 'jax-gcn'...
# remote: Enumerating objects: 99, done.
# remote: Counting objects: 100% (99/99), done.
# remote: Compressing objects: 100% (69/69), done.
# remote: Total 99 (delta 40), reused 81 (delta 26), pack-reused 0
# Unpacking objects: 100% (99/99), done.
# (2708, 1433)
# (2708, 2708)
# (2708, 7)

# %% [markdown]
# # Training Model
#
# We then train the model. This time we don't use the Stochastic gradient decent. We use the adam optimizer which comes from JAX. We don't need to implement the stochastic model manually We describe the approach using the multi layered GCNN.

# %%
adj, features, labels, idx_train, idx_val, idx_test = load_data()
rng_key = random.PRNGKey(10)
dropout = 0.9
step_size = 0.001
hidden = [128,64,32,labels.shape[1]]
num_epochs = 1000
n_nodes = features.shape[0]
n_feats = features.shape[1]
print(n_nodes)
print(n_feats)
early_stopping = 1e6


init_fun, predict_fun = GCN(nhid=hidden,
                            dropout=dropout)
input_shape = (-1, n_nodes, n_feats)
rng_key, init_key = random.split(rng_key)
_, init_params = init_fun(init_key, input_shape)
print(jax.tree_map(lambda x: x.shape, init_params))
opt_init, opt_update, get_params = optimizers.adam(step_size)


@jit
def update(i, opt_state, batch):
    params = get_params(opt_state)
    return opt_update(i, grad(loss)(params, batch), opt_state)

opt_state = opt_init(init_params)

print("\nStarting training...")
val_values = []
for epoch in range(num_epochs):
    start_time = time.time()
    batch = (features, labels, adj, True, rng_key)
    opt_state = update(epoch, opt_state, batch)
    epoch_time = time.time() - start_time
    
    params = get_params(opt_state)
    eval_batch = (features, labels, adj, False, rng_key)
    train_batch = (features, labels, adj, False, rng_key)
    train_loss, train_acc = loss_accuracy(params, train_batch)
    val_loss, val_acc = loss_accuracy(params, eval_batch)
    val_values.append(val_loss.item())
    print(f"Iter {epoch}/{num_epochs} ({epoch_time:.4f} s) train_loss: {train_loss:.4f}, train_acc: {train_acc:.4f}, val_loss: {val_loss:.4f}, val_acc: {val_acc:.4f}")

    # new random key at each iteration, othwerwise dropout uses always the same mask 
    rng_key, _ = random.split(rng_key)
    if epoch > early_stopping and val_values[-1] > numpy.mean(val_values[-(early_stopping+1):-1]):
        print("Early stopping...")
        break

# now run on the test set
test_batch = (features, labels, adj, False, rng_key)
test_acc = accuracy(params, test_batch)
print(f'Test set acc: {test_acc}')
# Out:
# 2708
# 1433
# [((1433, 128), None), ((128, 64), None), ((64, 32), None), ((32, 7), None)]
#
# Starting training...
# Iter 0/1000 (2.8981 s) train_loss: 1.9455, train_acc: 0.2315, val_loss: 1.9455, val_acc: 0.2315
# Iter 1/1000 (0.0333 s) train_loss: 1.9451, train_acc: 0.2947, val_loss: 1.9451, val_acc: 0.2947
# Iter 2/1000 (0.0339 s) train_loss: 1.9447, train_acc: 0.3386, val_loss: 1.9447, val_acc: 0.3386
# Iter 3/1000 (0.0377 s) train_loss: 1.9444, train_acc: 0.3859, val_loss: 1.9444, val_acc: 0.3859
# Iter 4/1000 (0.0332 s) train_loss: 1.9441, train_acc: 0.4069, val_loss: 1.9441, val_acc: 0.4069
# Iter 5/1000 (0.0338 s) train_loss: 1.9437, train_acc: 0.4143, val_loss: 1.9437, val_acc: 0.4143
# Iter 6/1000 (0.0377 s) train_loss: 1.9433, train_acc: 0.4129, val_loss: 1.9433, val_acc: 0.4129
# Iter 7/1000 (0.0340 s) train_loss: 1.9429, train_acc: 0.3992, val_loss: 1.9429, val_acc: 0.3992
# Iter 8/1000 (0.0343 s) train_loss: 1.9424, train_acc: 0.3756, val_loss: 1.9424, val_acc: 0.3756
# Iter 9/1000 (0.0354 s) train_loss: 1.9419, train_acc: 0.3600, val_loss: 1.9419, val_acc: 0.3600
# Iter 10/1000 (0.0350 s) train_loss: 1.9414, train_acc: 0.3479, val_loss: 1.9414, val_acc: 0.3479
# Iter 11/1000 (0.0358 s) train_loss: 1.9407, train_acc: 0.3379, val_loss: 1.9407, val_acc: 0.3379
# Iter 12/1000 (0.0369 s) train_loss: 1.9400, train_acc: 0.3287, val_loss: 1.9400, val_acc: 0.3287
# Iter 13/1000 (0.0337 s) train_loss: 1.9392, train_acc: 0.3102, val_loss: 1.9392, val_acc: 0.3102
# Iter 14/1000 (0.0332 s) train_loss: 1.9384, train_acc: 0.3069, val_loss: 1.9384, val_acc: 0.3069
# Iter 15/1000 (0.0363 s) train_loss: 1.9374, train_acc: 0.3061, val_loss: 1.9374, val_acc: 0.3061
# Iter 16/1000 (0.0359 s) train_loss: 1.9363, train_acc: 0.3061, val_loss: 1.9363, val_acc: 0.3061
# Iter 17/1000 (0.0345 s) train_loss: 1.9351, train_acc: 0.3047, val_loss: 1.9351, val_acc: 0.3047
# Iter 18/1000 (0.0349 s) train_loss: 1.9338, train_acc: 0.3047, val_loss: 1.9338, val_acc: 0.3047
# Iter 19/1000 (0.0350 s) train_loss: 1.9323, train_acc: 0.3039, val_loss: 1.9323, val_acc: 0.3039
# Iter 20/1000 (0.0361 s) train_loss: 1.9308, train_acc: 0.3035, val_loss: 1.9308, val_acc: 0.3035
# Iter 21/1000 (0.0331 s) train_loss: 1.9290, train_acc: 0.3021, val_loss: 1.9290, val_acc: 0.3021
# Iter 22/1000 (0.0338 s) train_loss: 1.9271, train_acc: 0.3021, val_loss: 1.9271, val_acc: 0.3021
# Iter 23/1000 (0.0351 s) train_loss: 1.9250, train_acc: 0.3021, val_loss: 1.9250, val_acc: 0.3021
# Iter 24/1000 (0.0332 s) train_loss: 1.9227, train_acc: 0.3021, val_loss: 1.9227, val_acc: 0.3021
# Iter 25/1000 (0.0341 s) train_loss: 1.9202, train_acc: 0.3021, val_loss: 1.9202, val_acc: 0.3021
# Iter 26/1000 (0.0364 s) train_loss: 1.9174, train_acc: 0.3021, val_loss: 1.9174, val_acc: 0.3021
# Iter 27/1000 (0.0343 s) train_loss: 1.9144, train_acc: 0.3021, val_loss: 1.9144, val_acc: 0.3021
# Iter 28/1000 (0.0340 s) train_loss: 1.9111, train_acc: 0.3021, val_loss: 1.9111, val_acc: 0.3021
# Iter 29/1000 (0.0361 s) train_loss: 1.9076, train_acc: 0.3021, val_loss: 1.9076, val_acc: 0.3021
# Iter 30/1000 (0.0372 s) train_loss: 1.9037, train_acc: 0.3021, val_loss: 1.9037, val_acc: 0.3021
# Iter 31/1000 (0.0343 s) train_loss: 1.8995, train_acc: 0.3021, val_loss: 1.8995, val_acc: 0.3021
# Iter 32/1000 (0.0364 s) train_loss: 1.8950, train_acc: 0.3021, val_loss: 1.8950, val_acc: 0.3021
# Iter 33/1000 (0.0342 s) train_loss: 1.8901, train_acc: 0.3021, val_loss: 1.8901, val_acc: 0.3021
# Iter 34/1000 (0.0335 s) train_loss: 1.8848, train_acc: 0.3021, val_loss: 1.8848, val_acc: 0.3021
# Iter 35/1000 (0.0365 s) train_loss: 1.8791, train_acc: 0.3021, val_loss: 1.8791, val_acc: 0.3021
# Iter 36/1000 (0.0330 s) train_loss: 1.8730, train_acc: 0.3021, val_loss: 1.8730, val_acc: 0.3021
# Iter 37/1000 (0.0345 s) train_loss: 1.8664, train_acc: 0.3021, val_loss: 1.8664, val_acc: 0.3021
# Iter 38/1000 (0.0419 s) train_loss: 1.8594, train_acc: 0.3021, val_loss: 1.8594, val_acc: 0.3021
# Iter 39/1000 (0.0347 s) train_loss: 1.8520, train_acc: 0.3021, val_loss: 1.8520, val_acc: 0.3021
# Iter 40/1000 (0.0335 s) train_loss: 1.8441, train_acc: 0.3021, val_loss: 1.8441, val_acc: 0.3021
# Iter 41/1000 (0.0372 s) train_loss: 1.8358, train_acc: 0.3021, val_loss: 1.8358, val_acc: 0.3021
# Iter 42/1000 (0.0337 s) train_loss: 1.8270, train_acc: 0.3021, val_loss: 1.8270, val_acc: 0.3021
# Iter 43/1000 (0.0330 s) train_loss: 1.8178, train_acc: 0.3021, val_loss: 1.8178, val_acc: 0.3021
# Iter 44/1000 (0.0364 s) train_loss: 1.8082, train_acc: 0.3021, val_loss: 1.8082, val_acc: 0.3021
# Iter 45/1000 (0.0334 s) train_loss: 1.7982, train_acc: 0.3021, val_loss: 1.7982, val_acc: 0.3021
# Iter 46/1000 (0.0334 s) train_loss: 1.7878, train_acc: 0.3028, val_loss: 1.7878, val_acc: 0.3028
# Iter 47/1000 (0.0385 s) train_loss: 1.7770, train_acc: 0.3028, val_loss: 1.7770, val_acc: 0.3028
# Iter 48/1000 (0.0336 s) train_loss: 1.7659, train_acc: 0.3028, val_loss: 1.7659, val_acc: 0.3028
# Iter 49/1000 (0.0341 s) train_loss: 1.7544, train_acc: 0.3028, val_loss: 1.7544, val_acc: 0.3028
# Iter 50/1000 (0.0348 s) train_loss: 1.7427, train_acc: 0.3032, val_loss: 1.7427, val_acc: 0.3032
# Iter 51/1000 (0.0345 s) train_loss: 1.7306, train_acc: 0.3032, val_loss: 1.7306, val_acc: 0.3032
# Iter 52/1000 (0.0332 s) train_loss: 1.7183, train_acc: 0.3035, val_loss: 1.7183, val_acc: 0.3035
# Iter 53/1000 (0.0363 s) train_loss: 1.7057, train_acc: 0.3050, val_loss: 1.7057, val_acc: 0.3050
# Iter 54/1000 (0.0342 s) train_loss: 1.6930, train_acc: 0.3058, val_loss: 1.6930, val_acc: 0.3058
# Iter 55/1000 (0.0338 s) train_loss: 1.6801, train_acc: 0.3120, val_loss: 1.6801, val_acc: 0.3120
# Iter 56/1000 (0.0354 s) train_loss: 1.6671, train_acc: 0.3213, val_loss: 1.6671, val_acc: 0.3213
# Iter 57/1000 (0.0340 s) train_loss: 1.6541, train_acc: 0.3301, val_loss: 1.6541, val_acc: 0.3301
# Iter 58/1000 (0.0331 s) train_loss: 1.6411, train_acc: 0.3486, val_loss: 1.6411, val_acc: 0.3486
# Iter 59/1000 (0.0393 s) train_loss: 1.6282, train_acc: 0.3748, val_loss: 1.6282, val_acc: 0.3748
# Iter 60/1000 (0.0338 s) train_loss: 1.6154, train_acc: 0.3951, val_loss: 1.6154, val_acc: 0.3951
# Iter 61/1000 (0.0349 s) train_loss: 1.6027, train_acc: 0.4121, val_loss: 1.6027, val_acc: 0.4121
# Iter 62/1000 (0.0361 s) train_loss: 1.5902, train_acc: 0.4232, val_loss: 1.5902, val_acc: 0.4232
# Iter 63/1000 (0.0339 s) train_loss: 1.5778, train_acc: 0.4332, val_loss: 1.5778, val_acc: 0.4332
# Iter 64/1000 (0.0349 s) train_loss: 1.5657, train_acc: 0.4409, val_loss: 1.5657, val_acc: 0.4409
# Iter 65/1000 (0.0355 s) train_loss: 1.5537, train_acc: 0.4531, val_loss: 1.5537, val_acc: 0.4531
# Iter 66/1000 (0.0343 s) train_loss: 1.5419, train_acc: 0.4597, val_loss: 1.5419, val_acc: 0.4597
# Iter 67/1000 (0.0348 s) train_loss: 1.5303, train_acc: 0.4620, val_loss: 1.5303, val_acc: 0.4620
# Iter 68/1000 (0.0343 s) train_loss: 1.5191, train_acc: 0.4686, val_loss: 1.5191, val_acc: 0.4686
# Iter 69/1000 (0.0331 s) train_loss: 1.5080, train_acc: 0.4742, val_loss: 1.5080, val_acc: 0.4742
# Iter 70/1000 (0.0363 s) train_loss: 1.4972, train_acc: 0.4819, val_loss: 1.4972, val_acc: 0.4819
# Iter 71/1000 (0.0364 s) train_loss: 1.4865, train_acc: 0.4882, val_loss: 1.4865, val_acc: 0.4882
# Iter 72/1000 (0.0337 s) train_loss: 1.4760, train_acc: 0.4930, val_loss: 1.4760, val_acc: 0.4930
# Iter 73/1000 (0.0339 s) train_loss: 1.4655, train_acc: 0.4982, val_loss: 1.4655, val_acc: 0.4982
# Iter 74/1000 (0.0354 s) train_loss: 1.4552, train_acc: 0.5066, val_loss: 1.4552, val_acc: 0.5066
# Iter 75/1000 (0.0331 s) train_loss: 1.4450, train_acc: 0.5107, val_loss: 1.4450, val_acc: 0.5107
# Iter 76/1000 (0.0343 s) train_loss: 1.4348, train_acc: 0.5151, val_loss: 1.4348, val_acc: 0.5151
# Iter 77/1000 (0.0359 s) train_loss: 1.4247, train_acc: 0.5214, val_loss: 1.4247, val_acc: 0.5214
# Iter 78/1000 (0.0333 s) train_loss: 1.4146, train_acc: 0.5251, val_loss: 1.4146, val_acc: 0.5251
# Iter 79/1000 (0.0332 s) train_loss: 1.4044, train_acc: 0.5281, val_loss: 1.4044, val_acc: 0.5281
# Iter 80/1000 (0.0355 s) train_loss: 1.3942, train_acc: 0.5321, val_loss: 1.3942, val_acc: 0.5321
# Iter 81/1000 (0.0349 s) train_loss: 1.3839, train_acc: 0.5395, val_loss: 1.3839, val_acc: 0.5395
# Iter 82/1000 (0.0374 s) train_loss: 1.3734, train_acc: 0.5469, val_loss: 1.3734, val_acc: 0.5469
# Iter 83/1000 (0.0359 s) train_loss: 1.3628, train_acc: 0.5517, val_loss: 1.3628, val_acc: 0.5517
# Iter 84/1000 (0.0353 s) train_loss: 1.3521, train_acc: 0.5587, val_loss: 1.3521, val_acc: 0.5587
# Iter 85/1000 (0.0340 s) train_loss: 1.3412, train_acc: 0.5650, val_loss: 1.3412, val_acc: 0.5650
# Iter 86/1000 (0.0350 s) train_loss: 1.3301, train_acc: 0.5713, val_loss: 1.3301, val_acc: 0.5713
# Iter 87/1000 (0.0328 s) train_loss: 1.3190, train_acc: 0.5879, val_loss: 1.3190, val_acc: 0.5879
# Iter 88/1000 (0.0346 s) train_loss: 1.3077, train_acc: 0.5960, val_loss: 1.3077, val_acc: 0.5960
# Iter 89/1000 (0.0356 s) train_loss: 1.2962, train_acc: 0.6056, val_loss: 1.2962, val_acc: 0.6056
# Iter 90/1000 (0.0337 s) train_loss: 1.2844, train_acc: 0.6160, val_loss: 1.2844, val_acc: 0.6160
# Iter 91/1000 (0.0346 s) train_loss: 1.2724, train_acc: 0.6193, val_loss: 1.2724, val_acc: 0.6193
# Iter 92/1000 (0.0372 s) train_loss: 1.2602, train_acc: 0.6292, val_loss: 1.2602, val_acc: 0.6292
# Iter 93/1000 (0.0339 s) train_loss: 1.2479, train_acc: 0.6355, val_loss: 1.2479, val_acc: 0.6355
# Iter 94/1000 (0.0343 s) train_loss: 1.2354, train_acc: 0.6481, val_loss: 1.2354, val_acc: 0.6481
# Iter 95/1000 (0.0354 s) train_loss: 1.2228, train_acc: 0.6566, val_loss: 1.2228, val_acc: 0.6566
# Iter 96/1000 (0.0330 s) train_loss: 1.2101, train_acc: 0.6673, val_loss: 1.2101, val_acc: 0.6673
# Iter 97/1000 (0.0330 s) train_loss: 1.1973, train_acc: 0.6747, val_loss: 1.1973, val_acc: 0.6747
# Iter 98/1000 (0.0368 s) train_loss: 1.1845, train_acc: 0.6754, val_loss: 1.1845, val_acc: 0.6754
# Iter 99/1000 (0.0336 s) train_loss: 1.1716, train_acc: 0.6780, val_loss: 1.1716, val_acc: 0.6780
# Iter 100/1000 (0.0337 s) train_loss: 1.1586, train_acc: 0.6802, val_loss: 1.1586, val_acc: 0.6802
# Iter 101/1000 (0.0373 s) train_loss: 1.1456, train_acc: 0.6817, val_loss: 1.1456, val_acc: 0.6817
# Iter 102/1000 (0.0341 s) train_loss: 1.1326, train_acc: 0.6809, val_loss: 1.1326, val_acc: 0.6809
# Iter 103/1000 (0.0337 s) train_loss: 1.1196, train_acc: 0.6806, val_loss: 1.1196, val_acc: 0.6806
# Iter 104/1000 (0.0348 s) train_loss: 1.1067, train_acc: 0.6776, val_loss: 1.1067, val_acc: 0.6776
# Iter 105/1000 (0.0337 s) train_loss: 1.0938, train_acc: 0.6680, val_loss: 1.0938, val_acc: 0.6680
# Iter 106/1000 (0.0331 s) train_loss: 1.0809, train_acc: 0.6617, val_loss: 1.0809, val_acc: 0.6617
# Iter 107/1000 (0.0365 s) train_loss: 1.0682, train_acc: 0.6573, val_loss: 1.0682, val_acc: 0.6573
# Iter 108/1000 (0.0329 s) train_loss: 1.0556, train_acc: 0.6599, val_loss: 1.0556, val_acc: 0.6599
# Iter 109/1000 (0.0357 s) train_loss: 1.0432, train_acc: 0.6603, val_loss: 1.0432, val_acc: 0.6603
# Iter 110/1000 (0.0356 s) train_loss: 1.0309, train_acc: 0.6614, val_loss: 1.0309, val_acc: 0.6614
# Iter 111/1000 (0.0345 s) train_loss: 1.0188, train_acc: 0.6629, val_loss: 1.0188, val_acc: 0.6629
# Iter 112/1000 (0.0356 s) train_loss: 1.0068, train_acc: 0.6643, val_loss: 1.0068, val_acc: 0.6643
# Iter 113/1000 (0.0356 s) train_loss: 0.9951, train_acc: 0.6654, val_loss: 0.9951, val_acc: 0.6654
# Iter 114/1000 (0.0330 s) train_loss: 0.9836, train_acc: 0.6673, val_loss: 0.9836, val_acc: 0.6673
# Iter 115/1000 (0.0330 s) train_loss: 0.9723, train_acc: 0.6695, val_loss: 0.9723, val_acc: 0.6695
# Iter 116/1000 (0.0370 s) train_loss: 0.9612, train_acc: 0.6710, val_loss: 0.9612, val_acc: 0.6710
# Iter 117/1000 (0.0338 s) train_loss: 0.9503, train_acc: 0.6721, val_loss: 0.9503, val_acc: 0.6721
# Iter 118/1000 (0.0344 s) train_loss: 0.9396, train_acc: 0.6739, val_loss: 0.9396, val_acc: 0.6739
# Iter 119/1000 (0.0360 s) train_loss: 0.9292, train_acc: 0.6739, val_loss: 0.9292, val_acc: 0.6739
# Iter 120/1000 (0.0333 s) train_loss: 0.9189, train_acc: 0.6758, val_loss: 0.9189, val_acc: 0.6758
# Iter 121/1000 (0.0342 s) train_loss: 0.9089, train_acc: 0.6761, val_loss: 0.9089, val_acc: 0.6761
# Iter 122/1000 (0.0341 s) train_loss: 0.8990, train_acc: 0.6773, val_loss: 0.8990, val_acc: 0.6773
# Iter 123/1000 (0.0355 s) train_loss: 0.8894, train_acc: 0.6780, val_loss: 0.8894, val_acc: 0.6780
# Iter 124/1000 (0.0332 s) train_loss: 0.8799, train_acc: 0.6802, val_loss: 0.8799, val_acc: 0.6802
# Iter 125/1000 (0.0370 s) train_loss: 0.8704, train_acc: 0.6824, val_loss: 0.8704, val_acc: 0.6824
# Iter 126/1000 (0.0338 s) train_loss: 0.8608, train_acc: 0.6876, val_loss: 0.8608, val_acc: 0.6876
# Iter 127/1000 (0.0374 s) train_loss: 0.8514, train_acc: 0.6939, val_loss: 0.8514, val_acc: 0.6939
# Iter 128/1000 (0.0350 s) train_loss: 0.8421, train_acc: 0.7016, val_loss: 0.8421, val_acc: 0.7016
# Iter 129/1000 (0.0342 s) train_loss: 0.8329, train_acc: 0.7168, val_loss: 0.8329, val_acc: 0.7168
# Iter 130/1000 (0.0333 s) train_loss: 0.8239, train_acc: 0.7249, val_loss: 0.8239, val_acc: 0.7249
# Iter 131/1000 (0.0371 s) train_loss: 0.8147, train_acc: 0.7341, val_loss: 0.8147, val_acc: 0.7341
# Iter 132/1000 (0.0332 s) train_loss: 0.8057, train_acc: 0.7456, val_loss: 0.8057, val_acc: 0.7456
# Iter 133/1000 (0.0333 s) train_loss: 0.7967, train_acc: 0.7552, val_loss: 0.7967, val_acc: 0.7552
# Iter 134/1000 (0.0375 s) train_loss: 0.7876, train_acc: 0.7603, val_loss: 0.7876, val_acc: 0.7603
# Iter 135/1000 (0.0335 s) train_loss: 0.7785, train_acc: 0.7640, val_loss: 0.7785, val_acc: 0.7640
# Iter 136/1000 (0.0394 s) train_loss: 0.7694, train_acc: 0.7677, val_loss: 0.7694, val_acc: 0.7677
# Iter 137/1000 (0.0358 s) train_loss: 0.7602, train_acc: 0.7696, val_loss: 0.7602, val_acc: 0.7696
# Iter 138/1000 (0.0347 s) train_loss: 0.7511, train_acc: 0.7710, val_loss: 0.7511, val_acc: 0.7710
# Iter 139/1000 (0.0349 s) train_loss: 0.7419, train_acc: 0.7725, val_loss: 0.7419, val_acc: 0.7725
# Iter 140/1000 (0.0377 s) train_loss: 0.7327, train_acc: 0.7733, val_loss: 0.7327, val_acc: 0.7733
# Iter 141/1000 (0.0349 s) train_loss: 0.7235, train_acc: 0.7751, val_loss: 0.7235, val_acc: 0.7751
# Iter 142/1000 (0.0329 s) train_loss: 0.7142, train_acc: 0.7762, val_loss: 0.7142, val_acc: 0.7762
# Iter 143/1000 (0.0363 s) train_loss: 0.7050, train_acc: 0.7762, val_loss: 0.7050, val_acc: 0.7762
# Iter 144/1000 (0.0340 s) train_loss: 0.6957, train_acc: 0.7758, val_loss: 0.6957, val_acc: 0.7758
# Iter 145/1000 (0.0336 s) train_loss: 0.6862, train_acc: 0.7773, val_loss: 0.6862, val_acc: 0.7773
# Iter 146/1000 (0.0344 s) train_loss: 0.6770, train_acc: 0.7781, val_loss: 0.6770, val_acc: 0.7781
# Iter 147/1000 (0.0348 s) train_loss: 0.6678, train_acc: 0.7792, val_loss: 0.6678, val_acc: 0.7792
# Iter 173/1000 (0.0355 s) train_loss: 0.4751, train_acc: 0.8852, val_loss: 0.4751, val_acc: 0.8852
# Iter 174/1000 (0.0327 s) train_loss: 0.4697, train_acc: 0.8885, val_loss: 0.4697, val_acc: 0.8885
# Iter 175/1000 (0.0331 s) train_loss: 0.4649, train_acc: 0.8896, val_loss: 0.4649, val_acc: 0.8896
# Iter 176/1000 (0.0343 s) train_loss: 0.4604, train_acc: 0.8900, val_loss: 0.4604, val_acc: 0.8900
# Iter 177/1000 (0.0336 s) train_loss: 0.4556, train_acc: 0.8900, val_loss: 0.4556, val_acc: 0.8900
# Iter 178/1000 (0.0327 s) train_loss: 0.4515, train_acc: 0.8903, val_loss: 0.4515, val_acc: 0.8903
# Iter 179/1000 (0.0365 s) train_loss: 0.4475, train_acc: 0.8896, val_loss: 0.4475, val_acc: 0.8896
# Iter 180/1000 (0.0344 s) train_loss: 0.4430, train_acc: 0.8903, val_loss: 0.4430, val_acc: 0.8903
# Iter 181/1000 (0.0335 s) train_loss: 0.4385, train_acc: 0.8922, val_loss: 0.4385, val_acc: 0.8922
# Iter 182/1000 (0.0352 s) train_loss: 0.4349, train_acc: 0.8929, val_loss: 0.4349, val_acc: 0.8929
# Iter 183/1000 (0.0335 s) train_loss: 0.4315, train_acc: 0.8955, val_loss: 0.4315, val_acc: 0.8955
# Iter 184/1000 (0.0346 s) train_loss: 0.4274, train_acc: 0.8940, val_loss: 0.4274, val_acc: 0.8940
# Iter 185/1000 (0.0421 s) train_loss: 0.4235, train_acc: 0.8948, val_loss: 0.4235, val_acc: 0.8948
# Iter 186/1000 (0.0333 s) train_loss: 0.4202, train_acc: 0.8959, val_loss: 0.4202, val_acc: 0.8959
# Iter 187/1000 (0.0415 s) train_loss: 0.4170, train_acc: 0.8955, val_loss: 0.4170, val_acc: 0.8955
# Iter 188/1000 (0.0371 s) train_loss: 0.4138, train_acc: 0.8959, val_loss: 0.4138, val_acc: 0.8959
# Iter 189/1000 (0.0337 s) train_loss: 0.4105, train_acc: 0.8973, val_loss: 0.4105, val_acc: 0.8973
# Iter 190/1000 (0.0348 s) train_loss: 0.4074, train_acc: 0.9003, val_loss: 0.4074, val_acc: 0.9003
# Iter 191/1000 (0.0386 s) train_loss: 0.4045, train_acc: 0.9010, val_loss: 0.4045, val_acc: 0.9010
# Iter 192/1000 (0.0346 s) train_loss: 0.4017, train_acc: 0.9007, val_loss: 0.4017, val_acc: 0.9007
# Iter 193/1000 (0.0351 s) train_loss: 0.3989, train_acc: 0.9021, val_loss: 0.3989, val_acc: 0.9021
# Iter 194/1000 (0.0368 s) train_loss: 0.3967, train_acc: 0.8992, val_loss: 0.3967, val_acc: 0.8992
# Iter 195/1000 (0.0351 s) train_loss: 0.3939, train_acc: 0.8999, val_loss: 0.3939, val_acc: 0.8999
# Iter 196/1000 (0.0345 s) train_loss: 0.3909, train_acc: 0.9040, val_loss: 0.3909, val_acc: 0.9040
# Iter 197/1000 (0.0358 s) train_loss: 0.3886, train_acc: 0.9044, val_loss: 0.3886, val_acc: 0.9044
# Iter 198/1000 (0.0352 s) train_loss: 0.3862, train_acc: 0.9040, val_loss: 0.3862, val_acc: 0.9040
# Iter 199/1000 (0.0338 s) train_loss: 0.3836, train_acc: 0.9040, val_loss: 0.3836, val_acc: 0.9040
# Iter 200/1000 (0.0349 s) train_loss: 0.3816, train_acc: 0.9032, val_loss: 0.3816, val_acc: 0.9032
# Iter 201/1000 (0.0347 s) train_loss: 0.3798, train_acc: 0.9036, val_loss: 0.3798, val_acc: 0.9036
# Iter 202/1000 (0.0336 s) train_loss: 0.3771, train_acc: 0.9040, val_loss: 0.3771, val_acc: 0.9040
# Iter 203/1000 (0.0360 s) train_loss: 0.3748, train_acc: 0.9066, val_loss: 0.3748, val_acc: 0.9066
# Iter 204/1000 (0.0345 s) train_loss: 0.3729, train_acc: 0.9073, val_loss: 0.3729, val_acc: 0.9073
# Iter 205/1000 (0.0338 s) train_loss: 0.3709, train_acc: 0.9069, val_loss: 0.3709, val_acc: 0.9069
# Iter 206/1000 (0.0372 s) train_loss: 0.3685, train_acc: 0.9055, val_loss: 0.3685, val_acc: 0.9055
# Iter 207/1000 (0.0329 s) train_loss: 0.3669, train_acc: 0.9044, val_loss: 0.3669, val_acc: 0.9044
# Iter 208/1000 (0.0334 s) train_loss: 0.3652, train_acc: 0.9036, val_loss: 0.3652, val_acc: 0.9036
# Iter 209/1000 (0.0352 s) train_loss: 0.3628, train_acc: 0.9058, val_loss: 0.3628, val_acc: 0.9058
# Iter 210/1000 (0.0326 s) train_loss: 0.3612, train_acc: 0.9088, val_loss: 0.3612, val_acc: 0.9088
# Iter 211/1000 (0.0335 s) train_loss: 0.3596, train_acc: 0.9092, val_loss: 0.3596, val_acc: 0.9092
# Iter 212/1000 (0.0421 s) train_loss: 0.3575, train_acc: 0.9099, val_loss: 0.3575, val_acc: 0.9099
# Iter 213/1000 (0.0336 s) train_loss: 0.3557, train_acc: 0.9088, val_loss: 0.3557, val_acc: 0.9088
# Iter 214/1000 (0.0330 s) train_loss: 0.3541, train_acc: 0.9084, val_loss: 0.3541, val_acc: 0.9084
# Iter 215/1000 (0.0355 s) train_loss: 0.3525, train_acc: 0.9095, val_loss: 0.3525, val_acc: 0.9095
# Iter 216/1000 (0.0349 s) train_loss: 0.3510, train_acc: 0.9095, val_loss: 0.3510, val_acc: 0.9095
# Iter 217/1000 (0.0339 s) train_loss: 0.3494, train_acc: 0.9084, val_loss: 0.3494, val_acc: 0.9084
# Iter 218/1000 (0.0359 s) train_loss: 0.3479, train_acc: 0.9084, val_loss: 0.3479, val_acc: 0.9084
# Iter 219/1000 (0.0359 s) train_loss: 0.3464, train_acc: 0.9117, val_loss: 0.3464, val_acc: 0.9117
# Iter 220/1000 (0.0331 s) train_loss: 0.3451, train_acc: 0.9117, val_loss: 0.3451, val_acc: 0.9117
# Iter 221/1000 (0.0395 s) train_loss: 0.3436, train_acc: 0.9121, val_loss: 0.3436, val_acc: 0.9121
# Iter 222/1000 (0.0334 s) train_loss: 0.3420, train_acc: 0.9103, val_loss: 0.3420, val_acc: 0.9103
# Iter 223/1000 (0.0339 s) train_loss: 0.3409, train_acc: 0.9106, val_loss: 0.3409, val_acc: 0.9106
# Iter 224/1000 (0.0361 s) train_loss: 0.3400, train_acc: 0.9092, val_loss: 0.3400, val_acc: 0.9092
# Iter 225/1000 (0.0329 s) train_loss: 0.3383, train_acc: 0.9117, val_loss: 0.3383, val_acc: 0.9117
# Iter 226/1000 (0.0336 s) train_loss: 0.3368, train_acc: 0.9117, val_loss: 0.3368, val_acc: 0.9117
# Iter 227/1000 (0.0359 s) train_loss: 0.3361, train_acc: 0.9158, val_loss: 0.3361, val_acc: 0.9158
# Iter 228/1000 (0.0349 s) train_loss: 0.3353, train_acc: 0.9158, val_loss: 0.3353, val_acc: 0.9158
# Iter 229/1000 (0.0343 s) train_loss: 0.3335, train_acc: 0.9162, val_loss: 0.3335, val_acc: 0.9162
# Iter 230/1000 (0.0362 s) train_loss: 0.3321, train_acc: 0.9121, val_loss: 0.3321, val_acc: 0.9121
# Iter 231/1000 (0.0333 s) train_loss: 0.3313, train_acc: 0.9132, val_loss: 0.3313, val_acc: 0.9132
# Iter 232/1000 (0.0336 s) train_loss: 0.3304, train_acc: 0.9121, val_loss: 0.3304, val_acc: 0.9121
# Iter 233/1000 (0.0364 s) train_loss: 0.3287, train_acc: 0.9121, val_loss: 0.3287, val_acc: 0.9121
# Iter 234/1000 (0.0336 s) train_loss: 0.3278, train_acc: 0.9147, val_loss: 0.3278, val_acc: 0.9147
# Iter 235/1000 (0.0339 s) train_loss: 0.3271, train_acc: 0.9147, val_loss: 0.3271, val_acc: 0.9147
# Iter 236/1000 (0.0366 s) train_loss: 0.3255, train_acc: 0.9151, val_loss: 0.3255, val_acc: 0.9151
# Iter 237/1000 (0.0333 s) train_loss: 0.3243, train_acc: 0.9125, val_loss: 0.3243, val_acc: 0.9125
# Iter 238/1000 (0.0344 s) train_loss: 0.3237, train_acc: 0.9121, val_loss: 0.3237, val_acc: 0.9121
# Iter 239/1000 (0.0385 s) train_loss: 0.3224, train_acc: 0.9121, val_loss: 0.3224, val_acc: 0.9121
# Iter 240/1000 (0.0329 s) train_loss: 0.3213, train_acc: 0.9154, val_loss: 0.3213, val_acc: 0.9154
# Iter 241/1000 (0.0335 s) train_loss: 0.3208, train_acc: 0.9151, val_loss: 0.3208, val_acc: 0.9151
# Iter 242/1000 (0.0359 s) train_loss: 0.3200, train_acc: 0.9158, val_loss: 0.3200, val_acc: 0.9158
# Iter 243/1000 (0.0337 s) train_loss: 0.3186, train_acc: 0.9154, val_loss: 0.3186, val_acc: 0.9154
# Iter 244/1000 (0.0326 s) train_loss: 0.3178, train_acc: 0.9129, val_loss: 0.3178, val_acc: 0.9129
# Iter 245/1000 (0.0358 s) train_loss: 0.3174, train_acc: 0.9110, val_loss: 0.3174, val_acc: 0.9110
# Iter 246/1000 (0.0382 s) train_loss: 0.3163, train_acc: 0.9114, val_loss: 0.3163, val_acc: 0.9114
# Iter 247/1000 (0.0345 s) train_loss: 0.3149, train_acc: 0.9169, val_loss: 0.3149, val_acc: 0.9169
# Iter 299/1000 (0.0356 s) train_loss: 0.2843, train_acc: 0.9154, val_loss: 0.2843, val_acc: 0.9154
# Iter 300/1000 (0.0330 s) train_loss: 0.2841, train_acc: 0.9165, val_loss: 0.2841, val_acc: 0.9165
# Iter 301/1000 (0.0354 s) train_loss: 0.2844, train_acc: 0.9165, val_loss: 0.2844, val_acc: 0.9165
# Iter 302/1000 (0.0364 s) train_loss: 0.2834, train_acc: 0.9169, val_loss: 0.2834, val_acc: 0.9169
# Iter 303/1000 (0.0341 s) train_loss: 0.2830, train_acc: 0.9169, val_loss: 0.2830, val_acc: 0.9169
# Iter 304/1000 (0.0384 s) train_loss: 0.2829, train_acc: 0.9177, val_loss: 0.2829, val_acc: 0.9177
# Iter 305/1000 (0.0355 s) train_loss: 0.2819, train_acc: 0.9177, val_loss: 0.2819, val_acc: 0.9177
# Iter 306/1000 (0.0345 s) train_loss: 0.2817, train_acc: 0.9177, val_loss: 0.2817, val_acc: 0.9177
# Iter 307/1000 (0.0337 s) train_loss: 0.2820, train_acc: 0.9177, val_loss: 0.2820, val_acc: 0.9177
# Iter 308/1000 (0.0364 s) train_loss: 0.2809, train_acc: 0.9188, val_loss: 0.2809, val_acc: 0.9188
# Iter 309/1000 (0.0332 s) train_loss: 0.2804, train_acc: 0.9173, val_loss: 0.2804, val_acc: 0.9173
# Iter 310/1000 (0.0339 s) train_loss: 0.2807, train_acc: 0.9173, val_loss: 0.2807, val_acc: 0.9173
# Iter 311/1000 (0.0398 s) train_loss: 0.2797, train_acc: 0.9177, val_loss: 0.2797, val_acc: 0.9177
# Iter 312/1000 (0.0329 s) train_loss: 0.2790, train_acc: 0.9158, val_loss: 0.2790, val_acc: 0.9158
# Iter 313/1000 (0.0333 s) train_loss: 0.2792, train_acc: 0.9173, val_loss: 0.2792, val_acc: 0.9173
# Iter 314/1000 (0.0372 s) train_loss: 0.2786, train_acc: 0.9169, val_loss: 0.2786, val_acc: 0.9169
# Iter 315/1000 (0.0337 s) train_loss: 0.2778, train_acc: 0.9173, val_loss: 0.2778, val_acc: 0.9173
# Iter 316/1000 (0.0340 s) train_loss: 0.2774, train_acc: 0.9162, val_loss: 0.2774, val_acc: 0.9162
# Iter 317/1000 (0.0358 s) train_loss: 0.2773, train_acc: 0.9158, val_loss: 0.2773, val_acc: 0.9158
# Iter 318/1000 (0.0333 s) train_loss: 0.2766, train_acc: 0.9162, val_loss: 0.2766, val_acc: 0.9162
# Iter 319/1000 (0.0331 s) train_loss: 0.2762, train_acc: 0.9173, val_loss: 0.2762, val_acc: 0.9173
# Iter 320/1000 (0.0357 s) train_loss: 0.2763, train_acc: 0.9169, val_loss: 0.2763, val_acc: 0.9169
# Iter 321/1000 (0.0344 s) train_loss: 0.2759, train_acc: 0.9165, val_loss: 0.2759, val_acc: 0.9165
# Iter 322/1000 (0.0324 s) train_loss: 0.2752, train_acc: 0.9162, val_loss: 0.2752, val_acc: 0.9162
# Iter 323/1000 (0.0349 s) train_loss: 0.2748, train_acc: 0.9173, val_loss: 0.2748, val_acc: 0.9173
# Iter 324/1000 (0.0322 s) train_loss: 0.2748, train_acc: 0.9195, val_loss: 0.2748, val_acc: 0.9195
# Iter 325/1000 (0.0335 s) train_loss: 0.2743, train_acc: 0.9177, val_loss: 0.2743, val_acc: 0.9177
# Iter 326/1000 (0.0366 s) train_loss: 0.2741, train_acc: 0.9169, val_loss: 0.2741, val_acc: 0.9169
# Iter 327/1000 (0.0330 s) train_loss: 0.2740, train_acc: 0.9173, val_loss: 0.2740, val_acc: 0.9173
# Iter 328/1000 (0.0354 s) train_loss: 0.2734, train_acc: 0.9173, val_loss: 0.2734, val_acc: 0.9173
# Iter 329/1000 (0.0357 s) train_loss: 0.2730, train_acc: 0.9169, val_loss: 0.2730, val_acc: 0.9169
# Iter 330/1000 (0.0338 s) train_loss: 0.2726, train_acc: 0.9188, val_loss: 0.2726, val_acc: 0.9188
# Iter 331/1000 (0.0354 s) train_loss: 0.2724, train_acc: 0.9191, val_loss: 0.2724, val_acc: 0.9191
# Iter 332/1000 (0.0371 s) train_loss: 0.2722, train_acc: 0.9177, val_loss: 0.2722, val_acc: 0.9177
# Iter 333/1000 (0.0347 s) train_loss: 0.2718, train_acc: 0.9188, val_loss: 0.2718, val_acc: 0.9188
# Iter 334/1000 (0.0345 s) train_loss: 0.2715, train_acc: 0.9191, val_loss: 0.2715, val_acc: 0.9191
# Iter 335/1000 (0.0368 s) train_loss: 0.2714, train_acc: 0.9195, val_loss: 0.2714, val_acc: 0.9195
# Iter 336/1000 (0.0381 s) train_loss: 0.2713, train_acc: 0.9188, val_loss: 0.2713, val_acc: 0.9188
# Iter 337/1000 (0.0342 s) train_loss: 0.2708, train_acc: 0.9199, val_loss: 0.2708, val_acc: 0.9199
# Iter 338/1000 (0.0367 s) train_loss: 0.2704, train_acc: 0.9195, val_loss: 0.2704, val_acc: 0.9195
# Iter 339/1000 (0.0331 s) train_loss: 0.2703, train_acc: 0.9177, val_loss: 0.2703, val_acc: 0.9177
# Iter 340/1000 (0.0334 s) train_loss: 0.2699, train_acc: 0.9184, val_loss: 0.2699, val_acc: 0.9184
# Iter 341/1000 (0.0355 s) train_loss: 0.2696, train_acc: 0.9169, val_loss: 0.2696, val_acc: 0.9169
# Iter 342/1000 (0.0343 s) train_loss: 0.2697, train_acc: 0.9184, val_loss: 0.2697, val_acc: 0.9184
# Iter 343/1000 (0.0335 s) train_loss: 0.2692, train_acc: 0.9177, val_loss: 0.2692, val_acc: 0.9177
# Iter 344/1000 (0.0380 s) train_loss: 0.2688, train_acc: 0.9180, val_loss: 0.2688, val_acc: 0.9180
# Iter 345/1000 (0.0342 s) train_loss: 0.2685, train_acc: 0.9191, val_loss: 0.2685, val_acc: 0.9191
# Iter 346/1000 (0.0345 s) train_loss: 0.2683, train_acc: 0.9188, val_loss: 0.2683, val_acc: 0.9188
# Iter 347/1000 (0.0362 s) train_loss: 0.2681, train_acc: 0.9177, val_loss: 0.2681, val_acc: 0.9177
# Iter 348/1000 (0.0334 s) train_loss: 0.2680, train_acc: 0.9180, val_loss: 0.2680, val_acc: 0.9180
# Iter 349/1000 (0.0337 s) train_loss: 0.2679, train_acc: 0.9177, val_loss: 0.2679, val_acc: 0.9177
# Iter 350/1000 (0.0370 s) train_loss: 0.2675, train_acc: 0.9180, val_loss: 0.2675, val_acc: 0.9180
# Iter 351/1000 (0.0341 s) train_loss: 0.2671, train_acc: 0.9184, val_loss: 0.2671, val_acc: 0.9184
# Iter 352/1000 (0.0340 s) train_loss: 0.2667, train_acc: 0.9199, val_loss: 0.2667, val_acc: 0.9199
# Iter 353/1000 (0.0361 s) train_loss: 0.2666, train_acc: 0.9202, val_loss: 0.2666, val_acc: 0.9202
# Iter 354/1000 (0.0326 s) train_loss: 0.2668, train_acc: 0.9213, val_loss: 0.2668, val_acc: 0.9213
# Iter 355/1000 (0.0360 s) train_loss: 0.2664, train_acc: 0.9217, val_loss: 0.2664, val_acc: 0.9217
# Iter 356/1000 (0.0362 s) train_loss: 0.2658, train_acc: 0.9206, val_loss: 0.2658, val_acc: 0.9206
# Iter 357/1000 (0.0337 s) train_loss: 0.2660, train_acc: 0.9184, val_loss: 0.2660, val_acc: 0.9184
# Iter 358/1000 (0.0341 s) train_loss: 0.2659, train_acc: 0.9184, val_loss: 0.2659, val_acc: 0.9184
# Iter 359/1000 (0.0343 s) train_loss: 0.2651, train_acc: 0.9206, val_loss: 0.2651, val_acc: 0.9206
# Iter 360/1000 (0.0336 s) train_loss: 0.2648, train_acc: 0.9210, val_loss: 0.2648, val_acc: 0.9210
# Iter 361/1000 (0.0342 s) train_loss: 0.2648, train_acc: 0.9202, val_loss: 0.2648, val_acc: 0.9202
# Iter 362/1000 (0.0367 s) train_loss: 0.2646, train_acc: 0.9210, val_loss: 0.2646, val_acc: 0.9210
# Iter 363/1000 (0.0390 s) train_loss: 0.2642, train_acc: 0.9210, val_loss: 0.2642, val_acc: 0.9210
# Iter 364/1000 (0.0337 s) train_loss: 0.2641, train_acc: 0.9221, val_loss: 0.2641, val_acc: 0.9221
# Iter 365/1000 (0.0368 s) train_loss: 0.2639, train_acc: 0.9221, val_loss: 0.2639, val_acc: 0.9221
# Iter 366/1000 (0.0345 s) train_loss: 0.2636, train_acc: 0.9217, val_loss: 0.2636, val_acc: 0.9217
# Iter 367/1000 (0.0342 s) train_loss: 0.2638, train_acc: 0.9195, val_loss: 0.2638, val_acc: 0.9195
# Iter 368/1000 (0.0400 s) train_loss: 0.2637, train_acc: 0.9206, val_loss: 0.2637, val_acc: 0.9206
# Iter 369/1000 (0.0342 s) train_loss: 0.2632, train_acc: 0.9188, val_loss: 0.2632, val_acc: 0.9188
# Iter 370/1000 (0.0341 s) train_loss: 0.2627, train_acc: 0.9199, val_loss: 0.2627, val_acc: 0.9199
# Iter 371/1000 (0.0372 s) train_loss: 0.2625, train_acc: 0.9202, val_loss: 0.2625, val_acc: 0.9202
# Iter 372/1000 (0.0344 s) train_loss: 0.2626, train_acc: 0.9213, val_loss: 0.2626, val_acc: 0.9213
# Iter 373/1000 (0.0341 s) train_loss: 0.2622, train_acc: 0.9210, val_loss: 0.2622, val_acc: 0.9210
# Iter 374/1000 (0.0346 s) train_loss: 0.2620, train_acc: 0.9206, val_loss: 0.2620, val_acc: 0.9206
# Iter 375/1000 (0.0339 s) train_loss: 0.2620, train_acc: 0.9213, val_loss: 0.2620, val_acc: 0.9213
# Iter 376/1000 (0.0338 s) train_loss: 0.2614, train_acc: 0.9206, val_loss: 0.2614, val_acc: 0.9206
# Iter 377/1000 (0.0372 s) train_loss: 0.2619, train_acc: 0.9210, val_loss: 0.2619, val_acc: 0.9210
# Iter 378/1000 (0.0343 s) train_loss: 0.2616, train_acc: 0.9217, val_loss: 0.2616, val_acc: 0.9217
# Iter 379/1000 (0.0341 s) train_loss: 0.2612, train_acc: 0.9202, val_loss: 0.2612, val_acc: 0.9202
# Iter 380/1000 (0.0356 s) train_loss: 0.2617, train_acc: 0.9213, val_loss: 0.2617, val_acc: 0.9213
# Iter 381/1000 (0.0341 s) train_loss: 0.2613, train_acc: 0.9232, val_loss: 0.2613, val_acc: 0.9232
# Iter 382/1000 (0.0333 s) train_loss: 0.2604, train_acc: 0.9217, val_loss: 0.2604, val_acc: 0.9217
# Iter 383/1000 (0.0366 s) train_loss: 0.2610, train_acc: 0.9210, val_loss: 0.2610, val_acc: 0.9210
# Iter 384/1000 (0.0333 s) train_loss: 0.2604, train_acc: 0.9225, val_loss: 0.2604, val_acc: 0.9225
# Iter 385/1000 (0.0326 s) train_loss: 0.2600, train_acc: 0.9206, val_loss: 0.2600, val_acc: 0.9206
# Iter 386/1000 (0.0354 s) train_loss: 0.2601, train_acc: 0.9210, val_loss: 0.2601, val_acc: 0.9210
# Iter 387/1000 (0.0342 s) train_loss: 0.2598, train_acc: 0.9217, val_loss: 0.2598, val_acc: 0.9217
# Iter 388/1000 (0.0346 s) train_loss: 0.2596, train_acc: 0.9213, val_loss: 0.2596, val_acc: 0.9213
# Iter 389/1000 (0.0357 s) train_loss: 0.2598, train_acc: 0.9202, val_loss: 0.2598, val_acc: 0.9202
# Iter 390/1000 (0.0338 s) train_loss: 0.2590, train_acc: 0.9210, val_loss: 0.2590, val_acc: 0.9210
# Iter 391/1000 (0.0340 s) train_loss: 0.2588, train_acc: 0.9206, val_loss: 0.2588, val_acc: 0.9206
# Iter 392/1000 (0.0368 s) train_loss: 0.2606, train_acc: 0.9225, val_loss: 0.2606, val_acc: 0.9225
# Iter 393/1000 (0.0340 s) train_loss: 0.2592, train_acc: 0.9213, val_loss: 0.2592, val_acc: 0.9213
# Iter 394/1000 (0.0349 s) train_loss: 0.2579, train_acc: 0.9232, val_loss: 0.2579, val_acc: 0.9232
# Iter 395/1000 (0.0362 s) train_loss: 0.2585, train_acc: 0.9210, val_loss: 0.2585, val_acc: 0.9210
# Iter 396/1000 (0.0343 s) train_loss: 0.2585, train_acc: 0.9213, val_loss: 0.2585, val_acc: 0.9213
# Iter 397/1000 (0.0330 s) train_loss: 0.2574, train_acc: 0.9210, val_loss: 0.2574, val_acc: 0.9210
# Iter 398/1000 (0.0367 s) train_loss: 0.2578, train_acc: 0.9225, val_loss: 0.2578, val_acc: 0.9225
# Iter 399/1000 (0.0339 s) train_loss: 0.2580, train_acc: 0.9232, val_loss: 0.2580, val_acc: 0.9232
# Iter 400/1000 (0.0367 s) train_loss: 0.2569, train_acc: 0.9217, val_loss: 0.2569, val_acc: 0.9217
# Iter 401/1000 (0.0346 s) train_loss: 0.2573, train_acc: 0.9221, val_loss: 0.2573, val_acc: 0.9221
# Iter 402/1000 (0.0333 s) train_loss: 0.2582, train_acc: 0.9199, val_loss: 0.2582, val_acc: 0.9199
# Iter 403/1000 (0.0333 s) train_loss: 0.2571, train_acc: 0.9213, val_loss: 0.2571, val_acc: 0.9213
# Iter 404/1000 (0.0347 s) train_loss: 0.2564, train_acc: 0.9217, val_loss: 0.2564, val_acc: 0.9217
# Iter 405/1000 (0.0343 s) train_loss: 0.2565, train_acc: 0.9228, val_loss: 0.2565, val_acc: 0.9228
# Iter 406/1000 (0.0343 s) train_loss: 0.2560, train_acc: 0.9210, val_loss: 0.2560, val_acc: 0.9210
# Iter 407/1000 (0.0361 s) train_loss: 0.2559, train_acc: 0.9228, val_loss: 0.2559, val_acc: 0.9228
# Iter 408/1000 (0.0343 s) train_loss: 0.2569, train_acc: 0.9195, val_loss: 0.2569, val_acc: 0.9195
# Iter 409/1000 (0.0341 s) train_loss: 0.2568, train_acc: 0.9206, val_loss: 0.2568, val_acc: 0.9206
# Iter 410/1000 (0.0403 s) train_loss: 0.2553, train_acc: 0.9221, val_loss: 0.2553, val_acc: 0.9221
# Iter 411/1000 (0.0342 s) train_loss: 0.2571, train_acc: 0.9243, val_loss: 0.2571, val_acc: 0.9243
# Iter 412/1000 (0.0331 s) train_loss: 0.2562, train_acc: 0.9243, val_loss: 0.2562, val_acc: 0.9243
# Iter 413/1000 (0.0357 s) train_loss: 0.2550, train_acc: 0.9225, val_loss: 0.2550, val_acc: 0.9225
# Iter 414/1000 (0.0329 s) train_loss: 0.2557, train_acc: 0.9206, val_loss: 0.2557, val_acc: 0.9206
# Iter 415/1000 (0.0333 s) train_loss: 0.2559, train_acc: 0.9202, val_loss: 0.2559, val_acc: 0.9202
# Iter 416/1000 (0.0343 s) train_loss: 0.2547, train_acc: 0.9217, val_loss: 0.2547, val_acc: 0.9217
# Iter 417/1000 (0.0336 s) train_loss: 0.2549, train_acc: 0.9228, val_loss: 0.2549, val_acc: 0.9228
# Iter 418/1000 (0.0338 s) train_loss: 0.2554, train_acc: 0.9239, val_loss: 0.2554, val_acc: 0.9239
# Iter 419/1000 (0.0359 s) train_loss: 0.2544, train_acc: 0.9228, val_loss: 0.2544, val_acc: 0.9228
# Iter 420/1000 (0.0334 s) train_loss: 0.2542, train_acc: 0.9221, val_loss: 0.2542, val_acc: 0.9221
# Iter 421/1000 (0.0330 s) train_loss: 0.2549, train_acc: 0.9210, val_loss: 0.2549, val_acc: 0.9210
# Iter 422/1000 (0.0361 s) train_loss: 0.2541, train_acc: 0.9217, val_loss: 0.2541, val_acc: 0.9217
# Iter 423/1000 (0.0331 s) train_loss: 0.2532, train_acc: 0.9217, val_loss: 0.2532, val_acc: 0.9217
# Iter 424/1000 (0.0348 s) train_loss: 0.2544, train_acc: 0.9213, val_loss: 0.2544, val_acc: 0.9213
# Iter 849/1000 (0.0332 s) train_loss: 0.2268, train_acc: 0.9280, val_loss: 0.2268, val_acc: 0.9280
# Iter 850/1000 (0.0368 s) train_loss: 0.2269, train_acc: 0.9280, val_loss: 0.2269, val_acc: 0.9280
# Iter 851/1000 (0.0336 s) train_loss: 0.2269, train_acc: 0.9284, val_loss: 0.2269, val_acc: 0.9284
# Iter 852/1000 (0.0339 s) train_loss: 0.2266, train_acc: 0.9284, val_loss: 0.2266, val_acc: 0.9284
# Iter 853/1000 (0.0358 s) train_loss: 0.2266, train_acc: 0.9276, val_loss: 0.2266, val_acc: 0.9276
# Iter 854/1000 (0.0353 s) train_loss: 0.2269, train_acc: 0.9280, val_loss: 0.2269, val_acc: 0.9280
# Iter 855/1000 (0.0339 s) train_loss: 0.2266, train_acc: 0.9306, val_loss: 0.2266, val_acc: 0.9306
# Iter 856/1000 (0.0383 s) train_loss: 0.2264, train_acc: 0.9295, val_loss: 0.2264, val_acc: 0.9295
# Iter 857/1000 (0.0331 s) train_loss: 0.2271, train_acc: 0.9287, val_loss: 0.2271, val_acc: 0.9287
# Iter 858/1000 (0.0338 s) train_loss: 0.2273, train_acc: 0.9280, val_loss: 0.2273, val_acc: 0.9280
# Iter 859/1000 (0.0371 s) train_loss: 0.2263, train_acc: 0.9291, val_loss: 0.2263, val_acc: 0.9291
# Iter 860/1000 (0.0343 s) train_loss: 0.2269, train_acc: 0.9298, val_loss: 0.2269, val_acc: 0.9298
# Iter 861/1000 (0.0345 s) train_loss: 0.2272, train_acc: 0.9273, val_loss: 0.2272, val_acc: 0.9273
# Iter 862/1000 (0.0357 s) train_loss: 0.2266, train_acc: 0.9291, val_loss: 0.2266, val_acc: 0.9291
# Iter 863/1000 (0.0351 s) train_loss: 0.2264, train_acc: 0.9284, val_loss: 0.2264, val_acc: 0.9284
# Iter 864/1000 (0.0341 s) train_loss: 0.2271, train_acc: 0.9276, val_loss: 0.2271, val_acc: 0.9276
# Iter 865/1000 (0.0379 s) train_loss: 0.2263, train_acc: 0.9276, val_loss: 0.2263, val_acc: 0.9276
# Iter 866/1000 (0.0335 s) train_loss: 0.2269, train_acc: 0.9269, val_loss: 0.2269, val_acc: 0.9269
# Iter 867/1000 (0.0342 s) train_loss: 0.2278, train_acc: 0.9265, val_loss: 0.2278, val_acc: 0.9265
# Iter 868/1000 (0.0365 s) train_loss: 0.2265, train_acc: 0.9261, val_loss: 0.2265, val_acc: 0.9261
# Iter 869/1000 (0.0346 s) train_loss: 0.2266, train_acc: 0.9258, val_loss: 0.2266, val_acc: 0.9258
# Iter 870/1000 (0.0335 s) train_loss: 0.2263, train_acc: 0.9261, val_loss: 0.2263, val_acc: 0.9261
# Iter 871/1000 (0.0365 s) train_loss: 0.2259, train_acc: 0.9258, val_loss: 0.2259, val_acc: 0.9258
# Iter 872/1000 (0.0338 s) train_loss: 0.2261, train_acc: 0.9269, val_loss: 0.2261, val_acc: 0.9269
# Iter 873/1000 (0.0338 s) train_loss: 0.2269, train_acc: 0.9284, val_loss: 0.2269, val_acc: 0.9284
# Iter 950/1000 (0.0334 s) train_loss: 0.2235, train_acc: 0.9306, val_loss: 0.2235, val_acc: 0.9306
# Iter 951/1000 (0.0338 s) train_loss: 0.2237, train_acc: 0.9284, val_loss: 0.2237, val_acc: 0.9284
# Iter 952/1000 (0.0365 s) train_loss: 0.2242, train_acc: 0.9280, val_loss: 0.2242, val_acc: 0.9280
# Iter 953/1000 (0.0338 s) train_loss: 0.2236, train_acc: 0.9291, val_loss: 0.2236, val_acc: 0.9291
# Iter 954/1000 (0.0335 s) train_loss: 0.2240, train_acc: 0.9280, val_loss: 0.2240, val_acc: 0.9280
# Iter 955/1000 (0.0387 s) train_loss: 0.2242, train_acc: 0.9276, val_loss: 0.2242, val_acc: 0.9276
# Iter 956/1000 (0.0332 s) train_loss: 0.2237, train_acc: 0.9284, val_loss: 0.2237, val_acc: 0.9284
# Iter 957/1000 (0.0356 s) train_loss: 0.2235, train_acc: 0.9306, val_loss: 0.2235, val_acc: 0.9306
# Iter 958/1000 (0.0352 s) train_loss: 0.2234, train_acc: 0.9317, val_loss: 0.2234, val_acc: 0.9317
# Iter 959/1000 (0.0338 s) train_loss: 0.2233, train_acc: 0.9302, val_loss: 0.2233, val_acc: 0.9302
# Iter 960/1000 (0.0361 s) train_loss: 0.2234, train_acc: 0.9306, val_loss: 0.2234, val_acc: 0.9306
# Iter 961/1000 (0.0369 s) train_loss: 0.2234, train_acc: 0.9302, val_loss: 0.2234, val_acc: 0.9302
# Iter 962/1000 (0.0335 s) train_loss: 0.2235, train_acc: 0.9302, val_loss: 0.2235, val_acc: 0.9302
# Iter 963/1000 (0.0343 s) train_loss: 0.2241, train_acc: 0.9280, val_loss: 0.2241, val_acc: 0.9280
# Iter 964/1000 (0.0374 s) train_loss: 0.2238, train_acc: 0.9295, val_loss: 0.2238, val_acc: 0.9295
# Iter 965/1000 (0.0340 s) train_loss: 0.2243, train_acc: 0.9280, val_loss: 0.2243, val_acc: 0.9280
# Iter 966/1000 (0.0341 s) train_loss: 0.2241, train_acc: 0.9295, val_loss: 0.2241, val_acc: 0.9295
# Iter 967/1000 (0.0364 s) train_loss: 0.2238, train_acc: 0.9291, val_loss: 0.2238, val_acc: 0.9291
# Iter 968/1000 (0.0355 s) train_loss: 0.2246, train_acc: 0.9298, val_loss: 0.2246, val_acc: 0.9298
# Iter 969/1000 (0.0350 s) train_loss: 0.2241, train_acc: 0.9291, val_loss: 0.2241, val_acc: 0.9291
# Iter 970/1000 (0.0362 s) train_loss: 0.2233, train_acc: 0.9280, val_loss: 0.2233, val_acc: 0.9280
# Iter 971/1000 (0.0349 s) train_loss: 0.2239, train_acc: 0.9250, val_loss: 0.2239, val_acc: 0.9250
# Iter 972/1000 (0.0334 s) train_loss: 0.2239, train_acc: 0.9254, val_loss: 0.2239, val_acc: 0.9254
# Iter 973/1000 (0.0392 s) train_loss: 0.2232, train_acc: 0.9276, val_loss: 0.2232, val_acc: 0.9276
# Iter 974/1000 (0.0336 s) train_loss: 0.2236, train_acc: 0.9291, val_loss: 0.2236, val_acc: 0.9291
